# %%
#Importing Libraries and Modules
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report,precision_recall_curve
import matplotlib.pyplot as plt
from sklearn import svm
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
#Data Read from CSV file.
data = pd.read_csv('C:\\Users\\shushens\\Desktop\\Feedbacks\\ID 3 10_1_18 Data & notebook\\bank.csv')
data.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
data.shape
# Out:
# (11162, 17)

# %%
y = data.deposit
y = y.to_frame()
y.head()
# Out:
#   deposit
# 0     yes
# 1     yes
# 2     yes
# 3     yes
# 4     yes

# %%
x = data
x.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
#Applying Train,Test Split 1st time
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=100)
#Print only columns of Training Data
X_train.columns
#Display first five records from X_train
X_train.head()
# Out:
#        age         job  marital  education default  balance housing loan  \
# 5541    45   housemaid  married    primary      no      317     yes   no
# 9240    53  management  married   tertiary      no      232     yes   no
# 10826   24     student   single  secondary      no      493     yes   no
# 1089    26  unemployed   single   tertiary      no      814      no   no
# 9168    55  technician  married    unknown      no     1393     yes  yes
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 5541    cellular    8   apr       325         2     -1         0  unknown
# 9240   telephone   29   jan        32         1     -1         0  unknown
# 10826   cellular   13   may        85         4    358         1    other
# 1089    cellular   28   jan      1387         1     -1         0  unknown
# 9168   telephone   21   nov        55         5     -1         0  unknown
#
#       deposit
# 5541       no
# 9240       no
# 10826      no
# 1089      yes
# ...

# %%
y_train.head()
# Out:
#       deposit
# 5541       no
# 9240       no
# 10826      no
# 1089      yes
# 9168       no

# %%
#The following code is added to convert all the string type data into numerical data 
combine_=[y_train,y_test]
depositmapping={'yes':1,'no': 0}
for dt in combine_:
   dt['deposit']=data['deposit'].map(depositmapping)

y_test.head()
y_train.head()
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#        deposit
# 5541         0
# 9240         0
# 10826        0
# 1089         1
# 9168         0

# %%
#assigning 1 to yes and 0 to no in default (X_train)
combine=[X_train,X_test]
depositmapping={'yes':1,'no': 0}
for dt in combine:
   dt['default']=data['default'].map(depositmapping)

X_train.head()




#assigning 1 to yes and 0 to no in default (X_train)
combine=[X_train,X_test]
depositmapping={'yes':1,'no': 0}
for dt in combine:
   dt['deposit']=data['deposit'].map(depositmapping)

X_train.head()

#assigning 1 to yes and 0 to no in default (X_train)
combine=[X_train,X_test]
defaultmapping={'yes':1,'no': 0}
for dt in combine:
   dt['default']=data['default'].map(defaultmapping)





#assigning 1 to yes and 0 to no in housing (X_train)
combine=[X_train,X_test]
housingmapping={'yes':1,'no': 0}
for dt in combine:
   dt['housing']=data['housing'].map(housingmapping)





#assigning 1 to yes and 0 to no in loan (X_train)
combine=[X_train,X_test]
loanmapping={'yes':1,'no': 0}
for dt in combine:
   dt['loan']=data['loan'].map(loanmapping)

#assigning 1 to yes and 0 to no in default (X_train)
combine=[X_train,X_test]
depositmapping={'cellular':1,'telephone': 0}
for dt in combine:
   dt['contact']=data['contact'].map(depositmapping)

X_train.head()
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#Analysing Marital variable to assign them numerical values
X_train[['marital','deposit']].groupby('marital',as_index=False).mean().sort_values('deposit',ascending=False)
# Out:
#     marital   deposit
# 2    single  0.553462
# 0  divorced  0.485640
# 1   married  0.436187

# %%
#Analysing Education variable to assign them numerical values
X_train[['education','deposit']].groupby('education',as_index=False).mean().sort_values('deposit',ascending=False)
# Out:
#    education   deposit
# 2   tertiary  0.541836
# 3    unknown  0.504886
# 1  secondary  0.458766
# 0    primary  0.390055

# %%
 educationmapping={'primary':1,'secondary':2,'tertiary':3,'unknown':0}
for df in combine:
    df['education']=df['education'].map(educationmapping)
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#analysing the variable 'month'
X_train[['month','deposit']].groupby('month',as_index=False).mean().sort_values('deposit',ascending=False)
# Out:
#    month   deposit
# 2    dec  0.945205
# 7    mar  0.890805
# 11   sep  0.862069
# 10   oct  0.828000
# 0    apr  0.617699
# 3    feb  0.534934
# 9    nov  0.441230
# 1    aug  0.439377
# 6    jun  0.438375
# 4    jan  0.432836
# 5    jul  0.423529
# 8    may  0.342703

# %%
for df in combine:
    df['month']=df['month'].replace(['mar','dec','sep','oct'],2,regex=True)
    df['month']=df['month'].replace(['apr','feb','aug','jun'],1,regex=True)
    df['month']=df['month'].replace(['nov','jul','jan','may'],0,regex=True)
X_train[['poutcome','deposit']].groupby('poutcome',as_index=False).mean().sort_values('deposit',ascending=False)
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
poutcomemapping={'success':2,'other':1,'failure':0,'unknown':0}

for df in combine:
    df['poutcome']=df['poutcome'].map(poutcomemapping)
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for df in combine:
    df['job']=df['job'].replace(['management','technician','unknown','admin.','housemaid','self-employed','services',
                                'blue-collar','entrepreneur'],'rare',regex=True)
jobmapping={'student':1,'retired':2,'unemployed':3,'rare':0}
for df in combine:
    df['job']=df['job'].map(jobmapping)
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_final_train=X_train[['job','loan','month','poutcome','education']]
X_final_test=X_test[['job','loan','month','poutcome','education']]

# %%
from sklearn.tree import  DecisionTreeClassifier
dt=DecisionTreeClassifier(random_state=101)
dt.fit(X_final_train,y_train)
predict=dt.predict(X_final_test)
accuracy_test=round(dt.score(X_final_test,y_test)*100,2)
accuracy_train=round(dt.score(X_final_train,y_train)*100,2)
print('train accuracy of decision tree classifier',accuracy_train)
print('test accuracy of decision tree classifier',accuracy_test)
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
cm = confusion_matrix(y_test, predict) 
print(cm)
cm_df = pd.DataFrame(cm,
                     index = ['Deposit','Others'], 
                     columns = ['Deposit','Others'])
plt.figure(figsize=(5.5,4))
sns.heatmap(cm_df, annot=True)
plt.title(' Decision Tree \nAccuracy:{0:.3f}'.format(accuracy_test))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# train accuracy of decision tree classifier 67.6
# test accuracy of decision tree classifier 66.27
# [[2157  227]
#  [1279  802]]

# %%
from sklearn.neighbors import KNeighborsClassifier
#Making KNN Model 
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_final_train,y_train)
knn.score(X_final_test,y_test)
#Prediction
y_pred = knn.predict(X_final_test)
print ('test accuracy of KNN classifier with N=3 is equal to :',(accuracy_score(y_test, y_pred)*100))
accuracy_test =(accuracy_score(y_test, y_pred)*100)
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
cm = confusion_matrix(y_test,y_pred) 
print(cm)
cm_df = pd.DataFrame(cm,
                     index = ['Deposit','Others'], 
                     columns = ['Deposit','Others'])
plt.figure(figsize=(5.5,4))
sns.heatmap(cm_df, annot=True)
plt.title(' KNN Classifier N=3 \nAccuracy:{0:.3f}'.format(accuracy_test))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   after removing the cwd from sys.path.
# test accuracy of KNN classifier with N=3 is equal to : 57.9843225084
# [[1256 1128]
#  [ 748 1333]]

# %%
#Model using SVM algorithm

# %%
sv = svm.SVC(gamma='auto')
sv.fit(X_final_train,y_train)
sv.score(X_final_test,y_test)
#Prediction
y_pred = sv.predict(X_final_test)
print ('test accuracy of SVM is equal to :',(accuracy_score(y_test, y_pred)*100))
accuracy_test =(accuracy_score(y_test, y_pred)*100)
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
cm = confusion_matrix(y_test,y_pred) 
print(cm)
cm_df = pd.DataFrame(cm,
                     index = ['Deposit','Others'], 
                     columns = ['Deposit','Others'])
plt.figure(figsize=(5.5,4))
sns.heatmap(cm_df, annot=True)
plt.title(' SVM Classifier  \nAccuracy:{0:.3f}'.format(accuracy_test))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# C:\Users\shushens\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# test accuracy of SVM is equal to : 66.718924972
# [[2138  246]
#  [1240  841]]
